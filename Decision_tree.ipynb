# %% [markdown]
# <a href="https://colab.research.google.com/github/turtulin/Research_Methodology/blob/dev/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gitkeep
